# %%
from binance import Client
import personal_function as pf
import pandas as pd
import numpy as np
import mplfinance as mpf
from binance.enums import *

# %%
client=pf.client()

# %%
info = client.get_account()
info

# %%
status = client.get_account_status()
status
# Out:
# {'data': 'Normal'}

# %%
fees = client.get_trade_fee()
fees
# Out:
# [{'symbol': '1INCHBTC',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': '1INCHBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': '1INCHDOWNUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': '1INCHUPUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': '1INCHUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'AAVEBKRW',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'AAVEBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'AAVEBRL', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'AAVEBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'AAVEBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'AAVEDOWNUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'AAVEETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'AAVEUPUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'AAVEUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'ACABTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ACABUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'ACAUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ACHBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ACHBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'ACHUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ACMBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ACMBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'ACMUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ADAAUD', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ADABIDR', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ADABKRW', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ADABNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ADABRL', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ADABTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ADABUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'ADADOWNUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'ADAETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ADAEUR', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ADAGBP', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ADAPAX', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ADARUB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ADATRY', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ADATUSD', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ADAUPUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'ADAUSDC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ADAUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ADXBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ADXBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ADXBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'ADXETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ADXUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'AEBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'AEBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'AEETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'AERGOBTC',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'AERGOBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'AGIBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'AGIBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'AGIETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'AGIXBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'AGLDBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'AGLDBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'AGLDBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'AGLDUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'AIONBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'AIONBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'AIONBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'AIONETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'AIONUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'AKROBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'AKROUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'ALCXBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ALCXBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'ALCXUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'ALGOBIDR',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'ALGOBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ALGOBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ALGOBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'ALGOPAX', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ALGORUB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ALGOTUSD',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'ALGOUSDC',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'ALGOUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'ALICEBIDR',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'ALICEBNB',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'ALICEBTC',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'ALICEBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'ALICETRY',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'ALICEUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'ALPACABNB',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'ALPACABTC',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'ALPACABUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'ALPACAUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'ALPHABNB',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'ALPHABTC',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'ALPHABUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'ALPHAUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'ALPINEBTC',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'ALPINEBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'ALPINEEUR',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'ALPINETRY',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'ALPINEUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'AMBBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'AMBBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'AMBETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'AMPBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'AMPBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'AMPBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'AMPUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ANCBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ANCBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ANCBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'ANCUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ANKRBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ANKRBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ANKRBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'ANKRPAX', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ANKRTUSD',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'ANKRUSDC',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'ANKRUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'ANTBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ANTBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ANTBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'ANTUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ANYBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ANYBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'ANYUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'APEBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'APEBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'APEBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'APEEUR', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'APEGBP', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'APETRY', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'APEUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'API3BNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'API3BTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'API3BUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'API3TRY', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'API3USDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'APPCBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'APPCBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'APPCETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ARBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ARBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ARBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'ARDRBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ARDRBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ARDRETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ARDRUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'ARKBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ARKETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ARNBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ARNETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ARPABNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ARPABTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ARPABUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'ARPARUB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ARPATRY', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ARPAUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'ARUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ASRBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ASRUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ASTBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ASTETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ASTRBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'ASTRUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'ATABNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ATABTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ATABUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'ATAUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ATMBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ATMBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'ATMUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ATOMBIDR',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'ATOMBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ATOMBRL', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ATOMBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ATOMBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'ATOMETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ATOMEUR', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ATOMPAX', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ATOMTRY', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ATOMTUSD',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'ATOMUSDC',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'ATOMUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'AUCTIONBTC',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'AUCTIONBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'AUCTIONUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'AUDBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'AUDIOBTC',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'AUDIOBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'AUDIOUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'AUDUSDC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'AUDUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'AUTOBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'AUTOBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'AUTOUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'AVABNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'AVABTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'AVABUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'AVAUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'AVAXAUD', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'AVAXBIDR',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'AVAXBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'AVAXBRL', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'AVAXBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'AVAXBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'AVAXETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'AVAXEUR', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'AVAXTRY', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'AVAXUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'AXSAUD', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'AXSBIDR', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'AXSBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'AXSBRL', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'AXSBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'AXSBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'AXSETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'AXSTRY', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'AXSUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BADGERBTC',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'BADGERBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'BADGERUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'BAKEBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BAKEBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BAKEBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'BAKEUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'BALBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BALBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BALBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'BALUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BANDBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BANDBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BANDBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'BANDUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'BARBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BARBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'BARUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BATBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BATBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BATBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'BATETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BATPAX', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BATTUSD', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BATUSDC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BATUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BCCBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BCCBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BCCETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BCCUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BCDBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BCDETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BCHABCBTC',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'BCHABCBUSD',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'BCHABCPAX',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'BCHABCTUSD',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'BCHABCUSDC',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'BCHABCUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'BCHABUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'BCHBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BCHBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BCHBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'BCHDOWNUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'BCHEUR', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BCHPAX', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BCHSVBTC',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'BCHSVPAX',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'BCHSVTUSD',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'BCHSVUSDC',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'BCHSVUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'BCHTUSD', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BCHUPUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'BCHUSDC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BCHUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BCNBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BCNBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BCNETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BCPTBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BCPTBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BCPTETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BCPTPAX', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BCPTTUSD',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'BCPTUSDC',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'BDOTDOT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BEAMBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BEAMBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BEAMUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'BEARBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'BEARUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'BELBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BELBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BELBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'BELTRY', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BELUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BETABNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BETABTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BETABUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'BETAETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BETAUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'BETHETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BGBPUSDC',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'BICOBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BICOBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'BICOUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'BIFIBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BIFIBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'BKRWBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'BKRWUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'BLZBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BLZBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BLZBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'BLZETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BLZUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BNBAUD', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BNBBEARBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'BNBBEARUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'BNBBIDR', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BNBBKRW', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BNBBRL', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BNBBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BNBBULLBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'BNBBULLUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'BNBBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'BNBDAI', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BNBDOWNUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'BNBETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BNBEUR', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BNBGBP', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BNBIDRT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BNBNGN', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BNBPAX', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BNBRUB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BNBTRY', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BNBTUSD', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BNBUAH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BNBUPUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'BNBUSDC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BNBUSDP', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BNBUSDS', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BNBUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BNBUST', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BNBZAR', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BNTBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BNTBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'BNTETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BNTUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BNXBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BNXBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BNXBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'BNXUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BONDBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BONDBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BONDBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'BONDUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'BOTBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BOTBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'BQXBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BQXETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BRDBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BRDBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BRDETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BSWBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BSWBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'BSWUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BTCAUD', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BTCBBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BTCBIDR', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BTCBKRW', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BTCBRL', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BTCBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'BTCDAI', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BTCDOWNUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'BTCEUR', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BTCGBP', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BTCGYEN', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BTCIDRT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BTCNGN', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BTCPAX', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BTCRUB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BTCSTBTC',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'BTCSTBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'BTCSTUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'BTCTRY', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BTCTUSD', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BTCUAH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BTCUPUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'BTCUSDC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BTCUSDP', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BTCUSDS', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BTCUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BTCVAI', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BTCZAR', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BTGBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BTGBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'BTGETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BTGUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BTSBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BTSBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BTSBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'BTSETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BTSUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BTTBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BTTBRL', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BTTBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BTTBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'BTTCTRY', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BTTCUSDC',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'BTTCUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'BTTEUR', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BTTPAX', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BTTTRX', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BTTTRY', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BTTTUSD', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BTTUSDC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BTTUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BULLBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'BULLUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'BURGERBNB',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'BURGERBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'BURGERUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'BUSDBIDR', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'BUSDBKRW', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'BUSDBRL', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'BUSDBVND', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'BUSDDAI', 'makerCommission': '0', 'takerCommission': '0'},
#  {'symbol': 'BUSDIDRT', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'BUSDNGN', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'BUSDRUB', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'BUSDTRY', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'BUSDUAH', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'BUSDUSDT', 'makerCommission': '0', 'takerCommission': '0'},
#  {'symbol': 'BUSDVAI', 'makerCommission': '0', 'takerCommission': '0'},
#  {'symbol': 'BUSDZAR', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'BZRXBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BZRXBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'BZRXBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'BZRXUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'C98BNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'C98BRL', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'C98BTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'C98BUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'C98USDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'CAKEAUD', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'CAKEBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'CAKEBRL', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'CAKEBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'CAKEBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'CAKEGBP', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'CAKEUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'CDTBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'CDTETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'CELOBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'CELOBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'CELOUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'CELRBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'CELRBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'CELRBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'CELRETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'CELRUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'CFXBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'CFXBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'CFXUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'CHATBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'CHATETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'CHESSBNB',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'CHESSBTC',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'CHESSBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'CHESSUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'CHRBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'CHRBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'CHRBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'CHRETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'CHRUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'CHZBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'CHZBRL', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'CHZBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'CHZBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'CHZEUR', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'CHZGBP', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'CHZTRY', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'CHZUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'CITYBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'CITYBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'CITYBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'CITYUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'CKBBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'CKBBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'CKBUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'CLOAKBTC',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'CLOAKETH',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'CLVBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'CLVBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'CLVBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'CLVUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'CMTBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'CMTBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'CMTETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'CNDBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'CNDBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'CNDETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'COCOSBNB',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'COCOSBTC',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'COCOSBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'COCOSTRY',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'COCOSUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'COMPBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'COMPBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'COMPBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'COMPUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'COSBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'COSBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'COSBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'COSTRY', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'COSUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'COTIBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'COTIBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'COTIBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'COTIUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'COVERBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'COVERETH',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'CREAMBNB',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'CREAMBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'CRVBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'CRVBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'CRVBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'CRVETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'CRVUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'CTKBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'CTKBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'CTKBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'CTKUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'CTSIBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'CTSIBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'CTSIBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'CTSIUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'CTXCBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'CTXCBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'CTXCBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'CTXCUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'CVCBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'CVCBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'CVCETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'CVCUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'CVPBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'CVPETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'CVPUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'CVXBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'CVXBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'CVXUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'DAIBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'DAIBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'DAIBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'DAIUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'DARBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'DARBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'DARBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'DARTRY', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'DARUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'DASHBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'DASHBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'DASHBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'DASHETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'DASHUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'DATABTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'DATABUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'DATAETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'DATAUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'DCRBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'DCRBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'DCRBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'DCRUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'DEGOBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'DEGOBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'DEGOUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'DENTBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'DENTBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'DENTETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'DENTTRY', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'DENTUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'DEXEBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'DEXEETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'DEXEUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'DFBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'DFETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'DFUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'DGBBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'DGBBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'DGBUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'DGDBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'DGDETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'DIABNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'DIABTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'DIABUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'DIAUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'DLTBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'DLTBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'DLTETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'DNTBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'DNTBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'DNTETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'DNTUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'DOCKBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'DOCKBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'DOCKETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
# ...
#  {'symbol': 'FRONTETH',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'FRONTUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'FTMAUD', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'FTMBIDR', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'FTMBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'FTMBRL', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'FTMBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'FTMBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'FTMETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'FTMPAX', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'FTMRUB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'FTMTRY', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'FTMTUSD', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'FTMUSDC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'FTMUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'FTTBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'FTTBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'FTTBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'FTTUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'FUELBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'FUELETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'FUNBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'FUNETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'FUNUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'FXSBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'FXSBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'FXSUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'GALAAUD', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'GALABNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'GALABRL', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'GALABTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'GALABUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'GALAETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'GALAEUR', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'GALATRY', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'GALAUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'GASBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'GBPBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'GBPUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'GHSTBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'GHSTETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'GHSTUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'GLMBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'GLMETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'GLMRBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'GLMRBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'GLMRBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'GLMRUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'GMTBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'GMTBRL', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'GMTBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'GMTBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'GMTETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'GMTUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'GNOBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'GNOBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'GNOBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'GNOUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'GNTBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'GNTBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'GNTETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'GOBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'GOBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'GRSBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'GRSETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'GRTBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'GRTBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'GRTETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'GRTEUR', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'GRTTRY', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'GRTUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'GTCBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'GTCBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'GTCBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'GTCUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'GTOBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'GTOBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'GTOETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'GTOPAX', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'GTOTUSD', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'GTOUSDC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'GTOUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'GVTBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'GVTETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'GXSBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'GXSBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'GXSETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'GXSUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'HARDBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'HARDBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'HARDBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'HARDUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'HBARBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'HBARBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'HBARBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'HBARUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'HCBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'HCETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'HCUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'HEGICBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'HEGICETH',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'HIGHBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'HIGHBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'HIGHBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'HIGHUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'HIVEBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'HIVEBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'HIVEBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'HIVEUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'HNTBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'HNTBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'HNTUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'HOTBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'HOTBRL', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'HOTBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'HOTBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'HOTETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'HOTEUR', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'HOTTRY', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'HOTUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'HSRBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'HSRETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ICNBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ICNETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ICPBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ICPBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ICPBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'ICPETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ICPEUR', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ICPRUB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ICPTRY', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ICPUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ICXBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ICXBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ICXBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'ICXETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ICXUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'IDEXBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'IDEXBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'IDEXBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'IDEXUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'ILVBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ILVBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'ILVBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'ILVUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'IMXBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'IMXBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'IMXUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'INJBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'INJBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'INJBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'INJTRY', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'INJUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'INSBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'INSETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'IOSTBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'IOSTBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'IOSTETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'IOSTUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'IOTABNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'IOTABTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'IOTABUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'IOTAETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'IOTAUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'IOTXBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'IOTXBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'IOTXETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'IOTXUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'IQBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'IQBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'IRISBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'IRISBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'IRISBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'IRISUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'JASMYBNB',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'JASMYBTC',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'JASMYBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'JASMYETH',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'JASMYTRY',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'JASMYUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'JOEBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'JOEBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'JOEUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'JSTBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'JSTBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'JSTBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'JSTUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'JUVBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'JUVBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'JUVUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'KAVABNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'KAVABTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'KAVABUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'KAVAETH', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'KAVAUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'KDABTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'KDABUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'KDAUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'KEEPBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'KEEPBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'KEEPBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  ...]

# %%
details = client.get_asset_details()
details
# Out:
# {'AGLD': {'withdrawFee': '12',
#   'minWithdrawAmount': '24',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'MXN': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'STPT': {'withdrawFee': '247',
#   'minWithdrawAmount': '494',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'UGX': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'RENBTC': {'withdrawFee': '0.00058',
#   'minWithdrawAmount': '0.0012',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'GLM': {'withdrawFee': '48',
#   'minWithdrawAmount': '96',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'RAY': {'withdrawFee': '0.34',
#   'minWithdrawAmount': '0.68',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'NEAR': {'withdrawFee': '0.01',
#   'minWithdrawAmount': '0.2',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'AUDIO': {'withdrawFee': '22',
#   'minWithdrawAmount': '44',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'HNT': {'withdrawFee': '0.05',
#   'minWithdrawAmount': '1',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'CDT': {'withdrawFee': '194',
#   'minWithdrawAmount': '388',
#   'withdrawStatus': False,
#   'depositStatus': True},
#  'ADADOWN': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': False,
#   'depositStatus': False,
#   'depositTip': ''},
#  'SPARTA': {'withdrawFee': '2',
#   'minWithdrawAmount': '4',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'SUSD': {'withdrawFee': '15',
#   'minWithdrawAmount': '30',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'FARM': {'withdrawFee': '0.002',
#   'minWithdrawAmount': '0.004',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'SDG': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': False,
#   'depositStatus': False},
#  'XNO': {'withdrawFee': '0.0093',
#   'minWithdrawAmount': '0.019',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'AION': {'withdrawFee': '0.1',
#   'minWithdrawAmount': '0.2',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'NPXS': {'withdrawFee': '4818',
#   'minWithdrawAmount': '9636',
#   'withdrawStatus': True,
#   'depositStatus': False},
#  'DGB': {'withdrawFee': '0.2',
#   'minWithdrawAmount': '0.4',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'DGD': {'withdrawFee': '0.026',
#   'minWithdrawAmount': '0.052',
#   'withdrawStatus': True,
#   'depositStatus': False,
#   'depositTip': 'Wallet Maintenance, Deposit Suspended'},
#  'ZRX': {'withdrawFee': '33',
#   'minWithdrawAmount': '66',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'BCD': {'withdrawFee': '0.01',
#   'minWithdrawAmount': '0.02',
#   'withdrawStatus': True,
#   'depositStatus': False,
#   'depositTip': 'Wallet Maintenance, Deposit Suspended'},
#  'EASY': {'withdrawFee': '1.96',
#   'minWithdrawAmount': '3.92',
#   'withdrawStatus': True,
#   'depositStatus': False},
#  'SANTOS': {'withdrawFee': '0.035',
#   'minWithdrawAmount': '0.07',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'WING': {'withdrawFee': '0.0033',
#   'minWithdrawAmount': '0.0066',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'AE': {'withdrawFee': '0.5',
#   'minWithdrawAmount': '1',
#   'withdrawStatus': False,
#   'depositStatus': False},
#  'WNXM': {'withdrawFee': '0.83',
#   'minWithdrawAmount': '1.66',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'BCH': {'withdrawFee': '0.001',
#   'minWithdrawAmount': '0.002',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'JST': {'withdrawFee': '50',
#   'minWithdrawAmount': '100',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'ADAUP': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': False,
#   'depositStatus': False,
#   'depositTip': ''},
#  'HOT': {'withdrawFee': '4135',
#   'minWithdrawAmount': '8270',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'GMT': {'withdrawFee': '0.59',
#   'minWithdrawAmount': '1.18',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'IRIS': {'withdrawFee': '1',
#   'minWithdrawAmount': '2',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'AR': {'withdrawFee': '0.03',
#   'minWithdrawAmount': '0.1',
#   'withdrawStatus': False,
#   'depositStatus': False},
#  'RAMP': {'withdrawFee': '265',
#   'minWithdrawAmount': '530',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'BCX': {'withdrawFee': '0.5',
#   'minWithdrawAmount': '0.5',
#   'withdrawStatus': True,
#   'depositStatus': False,
#   'depositTip': 'Not support deposit'},
#  'SEK': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': False,
#   'depositStatus': False},
#  'TRIG': {'withdrawFee': '50',
#   'minWithdrawAmount': '51',
#   'withdrawStatus': False,
#   'depositStatus': False,
#   'depositTip': 'Delisted, Deposit Suspended'},
#  'RCN': {'withdrawFee': '539',
#   'minWithdrawAmount': '1078',
#   'withdrawStatus': True,
#   'depositStatus': False,
#   'depositTip': 'Wallet Maintenance, Deposit Suspended'},
#  'COVER': {'withdrawFee': '0.005',
#   'minWithdrawAmount': '0.01',
#   'withdrawStatus': False,
#   'depositStatus': False,
#   'depositTip': 'Wallet Maintenance, Deposit Suspended'},
#  'FLM': {'withdrawFee': '0.5',
#   'minWithdrawAmount': '2',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'GNO': {'withdrawFee': '0.059',
#   'minWithdrawAmount': '0.12',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'GNT': {'withdrawFee': '0',
#   'minWithdrawAmount': '20',
#   'withdrawStatus': False,
#   'depositStatus': True},
#  'VITE': {'withdrawFee': '1',
#   'minWithdrawAmount': '2',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'BKRW': {'withdrawFee': '0',
#   'minWithdrawAmount': '20',
#   'withdrawStatus': True,
#   'depositStatus': False},
#  'CFX': {'withdrawFee': '1.24',
#   'minWithdrawAmount': '2.48',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'T': {'withdrawFee': '201',
#   'minWithdrawAmount': '402',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'XPR': {'withdrawFee': '1',
#   'minWithdrawAmount': '2',
#   'withdrawStatus': True,
#   'depositStatus': False},
#  'SFM': {'withdrawFee': '0',
#   'minWithdrawAmount': '1',
#   'withdrawStatus': False,
#   'depositStatus': True},
#  'SFP': {'withdrawFee': '0.19',
#   'minWithdrawAmount': '0.38',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'RDN': {'withdrawFee': '126',
#   'minWithdrawAmount': '252',
#   'withdrawStatus': True,
#   'depositStatus': False,
#   'depositTip': 'Wallet Maintenance, Deposit Suspended'},
#  'DIA': {'withdrawFee': '25',
#   'minWithdrawAmount': '50',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'ACA': {'withdrawFee': '0.2',
#   'minWithdrawAmount': '1',
#   'withdrawStatus': False,
#   'depositStatus': True},
#  'ARDR': {'withdrawFee': '2',
#   'minWithdrawAmount': '4',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'CLOAK': {'withdrawFee': '0.02',
#   'minWithdrawAmount': '0.02',
#   'withdrawStatus': False,
#   'depositStatus': False,
#   'depositTip': 'Delisted, Deposit Suspended'},
#  'LOOMOLD': {'withdrawFee': '0',
#   'minWithdrawAmount': '230',
#   'withdrawStatus': False,
#   'depositStatus': True},
#  'NEBL': {'withdrawFee': '0.01',
#   'minWithdrawAmount': '0.02',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'SLPOLD': {'withdrawFee': '0',
#   'minWithdrawAmount': '614',
#   'withdrawStatus': False,
#   'depositStatus': True},
#  'ACH': {'withdrawFee': '620',
#   'minWithdrawAmount': '1240',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'BEL': {'withdrawFee': '24',
#   'minWithdrawAmount': '48',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'JUV': {'withdrawFee': '0',
#   'minWithdrawAmount': '1',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'ACM': {'withdrawFee': '0',
#   'minWithdrawAmount': '1',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'MINA': {'withdrawFee': '0.5',
#   'minWithdrawAmount': '2.5',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'GRTDOWN': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': False,
#   'depositStatus': False,
#   'depositTip': 'Not support deposit'},
#  'VTHO': {'withdrawFee': '200',
#   'minWithdrawAmount': '400',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'PYROLD': {'withdrawFee': '2883',
#   'minWithdrawAmount': '5766',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'SGB': {'withdrawFee': '0.01',
#   'minWithdrawAmount': '0.02',
#   'withdrawStatus': True,
#   'depositStatus': False},
#  'SALT': {'withdrawFee': '5.2',
#   'minWithdrawAmount': '10.4',
#   'withdrawStatus': False,
#   'depositStatus': False,
#   'depositTip': 'Delisted, Deposit Suspended'},
#  'STORM': {'withdrawFee': '100',
#   'minWithdrawAmount': '200',
#   'withdrawStatus': True,
#   'depositStatus': False,
#   'depositTip': 'Network Swap, Deposit Closed'},
#  'WOO': {'withdrawFee': '0.34',
#   'minWithdrawAmount': '0.68',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'REN': {'withdrawFee': '56',
#   'minWithdrawAmount': '112',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'REP': {'withdrawFee': '1.65',
#   'minWithdrawAmount': '3.3',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'ADA': {'withdrawFee': '1',
#   'minWithdrawAmount': '10',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'ELF': {'withdrawFee': '67',
#   'minWithdrawAmount': '134',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'REQ': {'withdrawFee': '103',
#   'minWithdrawAmount': '206',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'STORJ': {'withdrawFee': '18',
#   'minWithdrawAmount': '36',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'HRK': {'withdrawFee': '1',
#   'minWithdrawAmount': '2',
#   'withdrawStatus': False,
#   'depositStatus': False},
#  'CHF': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': False,
#   'depositStatus': False},
#  'ADD': {'withdrawFee': '100',
#   'minWithdrawAmount': '200',
#   'withdrawStatus': True,
#   'depositStatus': False,
#   'depositTip': 'Not support deposit'},
#  'SGT': {'withdrawFee': '200',
#   'minWithdrawAmount': '400',
#   'withdrawStatus': True,
#   'depositStatus': False},
#  'BZRX': {'withdrawFee': '123',
#   'minWithdrawAmount': '246',
#   'withdrawStatus': False,
#   'depositStatus': True},
#  'DF': {'withdrawFee': '318',
#   'minWithdrawAmount': '636',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'RARE': {'withdrawFee': '40',
#   'minWithdrawAmount': '80',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'YOYO': {'withdrawFee': '1',
#   'minWithdrawAmount': '2',
#   'withdrawStatus': True,
#   'depositStatus': False},
#  'PAXG': {'withdrawFee': '0.014',
#   'minWithdrawAmount': '0.028',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'EOSDOWN': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': False,
#   'depositStatus': False,
#   'depositTip': ''},
#  'PAX': {'withdrawFee': '15',
#   'minWithdrawAmount': '30',
#   'withdrawStatus': False,
#   'depositStatus': True},
#  'CHR': {'withdrawFee': '48',
#   'minWithdrawAmount': '96',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'VND': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'BCHDOWN': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': False,
#   'depositStatus': False,
#   'depositTip': 'Not support deposit'},
#  'WAVES': {'withdrawFee': '0.002',
#   'minWithdrawAmount': '0.004',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'CHZ': {'withdrawFee': '0.72',
#   'minWithdrawAmount': '1.44',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'ADX': {'withdrawFee': '61',
#   'minWithdrawAmount': '122',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'XRP': {'withdrawFee': '0.25',
#   'minWithdrawAmount': '30',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'WPR': {'withdrawFee': '188.5',
#   'minWithdrawAmount': '377',
#   'withdrawStatus': True,
#   'depositStatus': False,
#   'depositTip': 'Wallet Maintenance, Deposit Suspended'},
#  'JASMY': {'withdrawFee': '720',
#   'minWithdrawAmount': '1440',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'AED': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': False,
#   'depositStatus': False,
#   'depositTip': ''},
#  'FIDA': {'withdrawFee': '0.62',
#   'minWithdrawAmount': '1.24',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'SAND': {'withdrawFee': '7.63',
#   'minWithdrawAmount': '15',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'DKK': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': False,
#   'depositStatus': False},
#  'OCEAN': {'withdrawFee': '40',
#   'minWithdrawAmount': '80',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'BGN': {'withdrawFee': '1',
#   'minWithdrawAmount': '2',
#   'withdrawStatus': False,
#   'depositStatus': False},
#  'UMA': {'withdrawFee': '3.38',
#   'minWithdrawAmount': '6.76',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'FOR': {'withdrawFee': '571',
#   'minWithdrawAmount': '1142',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'DREPOLD': {'withdrawFee': '0',
#   'minWithdrawAmount': '1322',
#   'withdrawStatus': True,
#   'depositStatus': False},
#  'SCRT': {'withdrawFee': '0.1',
#   'minWithdrawAmount': '0.2',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'TUSD': {'withdrawFee': '15',
#   'minWithdrawAmount': '30',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'EZ': {'withdrawFee': '11',
#   'minWithdrawAmount': '22',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'WABI': {'withdrawFee': '224',
#   'minWithdrawAmount': '448',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'TKO': {'withdrawFee': '0.27',
#   'minWithdrawAmount': '0.54',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'RGT': {'withdrawFee': '1.54',
#   'minWithdrawAmount': '3.08',
#   'withdrawStatus': False,
#   'depositStatus': True},
#  'ENG': {'withdrawFee': '400',
#   'minWithdrawAmount': '800',
#   'withdrawStatus': True,
#   'depositStatus': False},
#  'IDRT': {'withdrawFee': '389434',
#   'minWithdrawAmount': '778868',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'BHD': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': False,
#   'depositStatus': False},
#  'ENJ': {'withdrawFee': '15',
#   'minWithdrawAmount': '30',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'UNIDOWN': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': False,
#   'depositStatus': False,
#   'depositTip': 'Not support deposit'},
#  'KZT': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'YFII': {'withdrawFee': '0.011',
#   'minWithdrawAmount': '0.022',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'OAX': {'withdrawFee': '225',
#   'minWithdrawAmount': '450',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'GRT': {'withdrawFee': '55',
#   'minWithdrawAmount': '110',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'GRS': {'withdrawFee': '0.2',
#   'minWithdrawAmount': '0.4',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'TFUEL': {'withdrawFee': '2.35',
#   'minWithdrawAmount': '4.7',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'UND': {'withdrawFee': '5',
#   'minWithdrawAmount': '10',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'HARD': {'withdrawFee': '0.47',
#   'minWithdrawAmount': '0.94',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'ENS': {'withdrawFee': '1.39',
#   'minWithdrawAmount': '2.78',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'LEND': {'withdrawFee': '1',
#   'minWithdrawAmount': '2',
#   'withdrawStatus': False,
#   'depositStatus': True},
#  'DLT': {'withdrawFee': '811',
#   'minWithdrawAmount': '1622',
#   'withdrawStatus': True,
#   'depositStatus': False,
#   'depositTip': 'Wallet Maintenance, Deposit Suspended'},
#  'TROY': {'withdrawFee': '24',
#   'minWithdrawAmount': '48',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'XLMUP': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': False,
#   'depositStatus': False,
#   'depositTip': 'Not support deposit'},
#  'BTCDOWN': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': False,
#   'depositStatus': False,
#   'depositTip': 'Not support deposit'},
#  'UNI': {'withdrawFee': '2.29',
#   'minWithdrawAmount': '4.58',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'TLM': {'withdrawFee': '311',
#   'minWithdrawAmount': '622',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'SBTC': {'withdrawFee': '0.0005',
#   'minWithdrawAmount': '0.001',
#   'withdrawStatus': False,
#   'depositStatus': False,
#   'depositTip': 'Wallet Maintenance, Deposit Suspended'},
#  'HUF': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': False,
#   'depositStatus': False},
#  'CKB': {'withdrawFee': '1',
#   'minWithdrawAmount': '100',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'WRX': {'withdrawFee': '0.33',
#   'minWithdrawAmount': '0.66',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'XTZ': {'withdrawFee': '0.1',
#   'minWithdrawAmount': '1',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'LUNA': {'withdrawFee': '0.02',
#   'minWithdrawAmount': '0.25',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'ETHDOWN': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': False,
#   'depositStatus': False,
#   'depositTip': 'Not support deposit'},
#  'AGI': {'withdrawFee': '83',
#   'minWithdrawAmount': '166',
#   'withdrawStatus': False,
#   'depositStatus': False,
#   'depositTip': 'Wallet Maintenance, Deposit Suspended'},
#  'EON': {'withdrawFee': '10',
#   'minWithdrawAmount': '20',
#   'withdrawStatus': True,
#   'depositStatus': False,
#   'depositTip': 'Wallet Maintenance, Deposit Suspended'},
#  'BCHA': {'withdrawFee': '0.0034',
#   'minWithdrawAmount': '0.0068',
#   'withdrawStatus': False,
#   'depositStatus': True},
#  'EOP': {'withdrawFee': '5',
#   'minWithdrawAmount': '10',
#   'withdrawStatus': True,
#   'depositStatus': False,
#   'depositTip': 'Wallet Maintenance, Deposit Suspended'},
#  'EOS': {'withdrawFee': '0.1',
#   'minWithdrawAmount': '0.2',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'GO': {'withdrawFee': '1',
#   'minWithdrawAmount': '2',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'NCASH': {'withdrawFee': '83333',
#   'minWithdrawAmount': '166666',
#   'withdrawStatus': True,
#   'depositStatus': False},
#  'RIF': {'withdrawFee': '3',
#   'minWithdrawAmount': '6',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'EOSBULL': {'withdrawFee': '0.005',
#   'minWithdrawAmount': '0.01',
#   'withdrawStatus': False,
#   'depositStatus': False},
#  'NSBT': {'withdrawFee': '0.0063',
#   'minWithdrawAmount': '0.013',
#   'withdrawStatus': True,
#   'depositStatus': False},
#  'SKL': {'withdrawFee': '178',
#   'minWithdrawAmount': '356',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'XDATA': {'withdrawFee': '0',
#   'minWithdrawAmount': '286',
#   'withdrawStatus': False,
#   'depositStatus': True},
#  'GTC': {'withdrawFee': '5.97',
#   'minWithdrawAmount': '11',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'PEN': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': False,
#   'depositStatus': True},
#  'BLINK': {'withdrawFee': '50',
#   'minWithdrawAmount': '100',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'SOLO': {'withdrawFee': '0',
#   'minWithdrawAmount': '0.1',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'SXPDOWN': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': False,
#   'depositStatus': False,
#   'depositTip': ''},
#  'TMT': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'HC': {'withdrawFee': '0.005',
#   'minWithdrawAmount': '0.01',
#   'withdrawStatus': False,
#   'depositStatus': False},
#  'SKY': {'withdrawFee': '0.02',
#   'minWithdrawAmount': '0.04',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'NAS': {'withdrawFee': '0.1',
#   'minWithdrawAmount': '0.2',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'BURGER': {'withdrawFee': '0.13',
#   'minWithdrawAmount': '0.26',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'NAV': {'withdrawFee': '0.2',
#   'minWithdrawAmount': '0.4',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'GTO': {'withdrawFee': '4.71',
#   'minWithdrawAmount': '9.42',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'WTC': {'withdrawFee': '0.01',
#   'minWithdrawAmount': '1',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'XVG': {'withdrawFee': '0.1',
#   'minWithdrawAmount': '0.2',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'TNB': {'withdrawFee': '8928',
#   'minWithdrawAmount': '17856',
#   'withdrawStatus': False,
#   'depositStatus': False},
#  'EPS': {'withdrawFee': '1.07',
#   'minWithdrawAmount': '2.14',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'DNT': {'withdrawFee': '969',
#   'minWithdrawAmount': '1938',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'TND': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': False,
#   'depositStatus': False},
#  'BULL': {'withdrawFee': '0',
#   'minWithdrawAmount': '0.0000001',
#   'withdrawStatus': False,
#   'depositStatus': False},
#  'CLV': {'withdrawFee': '64',
#   'minWithdrawAmount': '128',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'FLOW': {'withdrawFee': '0.01',
#   'minWithdrawAmount': '2.7',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'XTZDOWN': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': False,
#   'depositStatus': False,
#   'depositTip': 'Not support deposit'},
#  'STEEM': {'withdrawFee': '0.01',
#   'minWithdrawAmount': '0.02',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'XVS': {'withdrawFee': '0.02',
#   'minWithdrawAmount': '0.04',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'BVND': {'withdrawFee': '6543',
#   'minWithdrawAmount': '13086',
#   'withdrawStatus': False,
#   'depositStatus': False,
#   'depositTip': 'Wallet Maintenance, Deposit Suspended'},
#  'SLP': {'withdrawFee': '1341',
#   'minWithdrawAmount': '2682',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'VRT': {'withdrawFee': '47',
#   'minWithdrawAmount': '94',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'TNT': {'withdrawFee': '2070',
#   'minWithdrawAmount': '4140',
#   'withdrawStatus': False,
#   'depositStatus': False,
#   'depositTip': 'TNT contract has been permanently paused. We are unable to provide withdrawal and deposit services for this token. Please reach out to TNT project team for assistance. ##https://medium.com/tierion/tierion-announces-settlement-with-u-s-securities-and-exchange-commission-f31b92878f53##'},
#  'NBS': {'withdrawFee': '1',
#   'minWithdrawAmount': '2',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'NBT': {'withdrawFee': '5',
#   'minWithdrawAmount': '10',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'DON': {'withdrawFee': '0.0093',
#   'minWithdrawAmount': '0.019',
#   'withdrawStatus': True,
#   'depositStatus': False},
#  'LAZIO': {'withdrawFee': '0.052',
#   'minWithdrawAmount': '0.1',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'IQ': {'withdrawFee': '50',
#   'minWithdrawAmount': '100',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'DOT': {'withdrawFee': '0.1',
#   'minWithdrawAmount': '1.5',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'CMT': {'withdrawFee': '1',
#   'minWithdrawAmount': '2',
#   'withdrawStatus': False,
#   'depositStatus': False},
#  'GRTUP': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': False,
#   'depositStatus': False,
#   'depositTip': 'Not support deposit'},
#  '1INCH': {'withdrawFee': '14',
#   'minWithdrawAmount': '28',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'KNCL': {'withdrawFee': '4',
#   'minWithdrawAmount': '8',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'XRPBULL': {'withdrawFee': '0.076',
#   'minWithdrawAmount': '0.15',
#   'withdrawStatus': False,
#   'depositStatus': False},
#  'CHESS': {'withdrawFee': '0.23',
#   'minWithdrawAmount': '0.46',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'MITH': {'withdrawFee': '5.4',
#   'minWithdrawAmount': '10',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'ERD': {'withdrawFee': '1.5',
#   'minWithdrawAmount': '3',
#   'withdrawStatus': True,
#   'depositStatus': False,
#   'depositTip': 'Wallet Maintenance, Deposit Suspended'},
#  'DEGO': {'withdrawFee': '7.46',
#   'minWithdrawAmount': '14',
#   'withdrawStatus': False,
#   'depositStatus': False},
#  'CND': {'withdrawFee': '6866',
#   'minWithdrawAmount': '13732',
#   'withdrawStatus': True,
#   'depositStatus': False,
#   'depositTip': 'Wallet Maintenance, Deposit Suspended'},
#  'GYEN': {'withdrawFee': '1201',
#   'minWithdrawAmount': '2402',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'UNFI': {'withdrawFee': '4.28',
#   'minWithdrawAmount': '8.56',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'FTM': {'withdrawFee': '0.01',
#   'minWithdrawAmount': '10',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'POWR': {'withdrawFee': '46',
#   'minWithdrawAmount': '92',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'ERN': {'withdrawFee': '4.49',
#   'minWithdrawAmount': '8.98',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'GVT': {'withdrawFee': '32',
#   'minWithdrawAmount': '64',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'WINGS': {'withdrawFee': '0',
#   'minWithdrawAmount': '40',
#   'withdrawStatus': False,
#   'depositStatus': False},
#  'FTT': {'withdrawFee': '0.53',
#   'minWithdrawAmount': '1.06',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'VOXEL': {'withdrawFee': '0.18',
#   'minWithdrawAmount': '0.36',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'RLC': {'withdrawFee': '11',
#   'minWithdrawAmount': '22',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'PHA': {'withdrawFee': '16',
#   'minWithdrawAmount': '32',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'PHB': {'withdrawFee': '0.87',
#   'minWithdrawAmount': '1.74',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'TRXDOWN': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': False,
#   'depositStatus': False,
#   'depositTip': ''},
#  'ATOM': {'withdrawFee': '0.005',
#   'minWithdrawAmount': '0.01',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'XRPUP': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': False,
#   'depositStatus': False,
#   'depositTip': ''},
#  'QUICK': {'withdrawFee': '0.0015',
#   'minWithdrawAmount': '0.003',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'BLZ': {'withdrawFee': '136',
#   'minWithdrawAmount': '272',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'SNM': {'withdrawFee': '162',
#   'minWithdrawAmount': '324',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'BOBA': {'withdrawFee': '8.56',
#   'minWithdrawAmount': '17',
#   'withdrawStatus': True,
#   'depositStatus': False},
#  'MBL': {'withdrawFee': '2.68',
#   'minWithdrawAmount': '5.36',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'BNBUP': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': False,
#   'depositStatus': False,
#   'depositTip': 'Not support deposit'},
#  'MTLX': {'withdrawFee': '1.5',
#   'minWithdrawAmount': '3',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'SNT': {'withdrawFee': '329',
#   'minWithdrawAmount': '658',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'PHP': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'SNX': {'withdrawFee': '7.1',
#   'minWithdrawAmount': '14',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'LTCDOWN': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': False,
#   'depositStatus': False,
#   'depositTip': 'Not support deposit'},
#  'FUN': {'withdrawFee': '2366',
#   'minWithdrawAmount': '4732',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'SNMOLD': {'withdrawFee': '319',
#   'minWithdrawAmount': '638',
#   'withdrawStatus': True,
#   'depositStatus': False},
#  'COP': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'COS': {'withdrawFee': '11',
#   'minWithdrawAmount': '22',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'USD': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'API3': {'withdrawFee': '4.69',
#   'minWithdrawAmount': '9.38',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'QKC': {'withdrawFee': '1109',
#   'minWithdrawAmount': '2218',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'ROSE': {'withdrawFee': '0.1',
#   'minWithdrawAmount': '1',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'SUSHIUP': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': False,
#   'depositStatus': False,
#   'depositTip': 'Not support deposit'},
#  'GLMR': {'withdrawFee': '0.5',
#   'minWithdrawAmount': '1',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'XYM': {'withdrawFee': '0.1',
#   'minWithdrawAmount': '0.2',
#   'withdrawStatus': True,
#   'depositStatus': False},
#  'PURSE': {'withdrawFee': '174',
#   'minWithdrawAmount': '348',
#   'withdrawStatus': True,
#   'depositStatus': False},
#  'SOL': {'withdrawFee': '0',
#   'minWithdrawAmount': '0.0002',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'TRXUP': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': False,
#   'depositStatus': False,
#   'depositTip': ''},
#  'CITY': {'withdrawFee': '0',
#   'minWithdrawAmount': '1',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'ETC': {'withdrawFee': '0.01',
#   'minWithdrawAmount': '0.02',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'BNC': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': False,
#   'depositStatus': False},
#  'ETF': {'withdrawFee': '1',
#   'minWithdrawAmount': '2',
#   'withdrawStatus': False,
#   'depositStatus': False,
#   'depositTip': 'Waiting for wallet development of ETF team'},
#  'BNB': {'withdrawFee': '0.0005',
#   'minWithdrawAmount': '0.01',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'CELR': {'withdrawFee': '480',
#   'minWithdrawAmount': '960',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'OGN': {'withdrawFee': '40',
#   'minWithdrawAmount': '80',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'UST': {'withdrawFee': '1',
#   'minWithdrawAmount': '50',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'ETH': {'withdrawFee': '0.002',
#   'minWithdrawAmount': '0.01',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'MCO': {'withdrawFee': '1.41',
#   'minWithdrawAmount': '2.82',
#   'withdrawStatus': False,
#   'depositStatus': False,
#   'depositTip': 'Wallet Maintenance, Deposit Suspended'},
#  'NEO': {'withdrawFee': '0',
#   'minWithdrawAmount': '1',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'TOMO': {'withdrawFee': '0.01',
#   'minWithdrawAmount': '0.02',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'CELO': {'withdrawFee': '0.001',
#   'minWithdrawAmount': '0.002',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'KLAY': {'withdrawFee': '0.005',
#   'minWithdrawAmount': '1',
#   'withdrawStatus': False,
#   'depositStatus': False},
#  'AUCTION': {'withdrawFee': '1.62',
#   'minWithdrawAmount': '3.24',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'BADGER': {'withdrawFee': '2.47',
#   'minWithdrawAmount': '4.94',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'GXS': {'withdrawFee': '0.3',
#   'minWithdrawAmount': '0.6',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'HIGH': {'withdrawFee': '3.53',
#   'minWithdrawAmount': '7.06',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'TRB': {'withdrawFee': '1.04',
#   'minWithdrawAmount': '2.08',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'BNT': {'withdrawFee': '9.81',
#   'minWithdrawAmount': '19',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'QLC': {'withdrawFee': '1',
#   'minWithdrawAmount': '2',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'LBA': {'withdrawFee': '10',
#   'minWithdrawAmount': '20',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'MDA': {'withdrawFee': '61',
#   'minWithdrawAmount': '122',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'UTK': {'withdrawFee': '100',
#   'minWithdrawAmount': '200',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'BNX': {'withdrawFee': '0.0041',
#   'minWithdrawAmount': '0.0082',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'EOSBEAR': {'withdrawFee': '0.022',
#   'minWithdrawAmount': '0.044',
#   'withdrawStatus': False,
#   'depositStatus': False},
#  'WSOL': {'withdrawFee': '0.01',
#   'minWithdrawAmount': '0.3',
#   'withdrawStatus': False,
#   'depositStatus': True},
#  'HEGIC': {'withdrawFee': '594',
#   'minWithdrawAmount': '1188',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'MA': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': False,
#   'depositStatus': False},
#  'AMB': {'withdrawFee': '1',
#   'minWithdrawAmount': '2',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'TRU': {'withdrawFee': '109',
#   'minWithdrawAmount': '218',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'MC': {'withdrawFee': '9.84',
#   'minWithdrawAmount': '19',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'FUEL': {'withdrawFee': '564',
#   'minWithdrawAmount': '1128',
#   'withdrawStatus': False,
#   'depositStatus': False},
#  'WBNB': {'withdrawFee': '0.002',
#   'minWithdrawAmount': '0.01',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'DREP': {'withdrawFee': '37',
#   'minWithdrawAmount': '74',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'TRY': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'TRX': {'withdrawFee': '1',
#   'minWithdrawAmount': '2',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'MDT': {'withdrawFee': '468',
#   'minWithdrawAmount': '936',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'NFT': {'withdrawFee': '1720',
#   'minWithdrawAmount': '3440',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'MDX': {'withdrawFee': '0.83',
#   'minWithdrawAmount': '1.66',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'XRPDOWN': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': False,
#   'depositStatus': False,
#   'depositTip': ''},
#  'AERGO': {'withdrawFee': '93',
#   'minWithdrawAmount': '186',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'EUR': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'AMP': {'withdrawFee': '977',
#   'minWithdrawAmount': '1954',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'BOT': {'withdrawFee': '0.011',
#   'minWithdrawAmount': '0.022',
#   'withdrawStatus': False,
#   'depositStatus': True},
#  'NULS': {'withdrawFee': '0.01',
#   'minWithdrawAmount': '0.02',
#   'withdrawStatus': False,
#   'depositStatus': True},
#  'AUTO': {'withdrawFee': '0.00048',
#   'minWithdrawAmount': '0.00096',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'NGN': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'ANC': {'withdrawFee': '0.2',
#   'minWithdrawAmount': '1.3',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'BDOT': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': False,
#   'depositStatus': False},
#  'EGLD': {'withdrawFee': '0.001',
#   'minWithdrawAmount': '0.01',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'ANTOLD': {'withdrawFee': '1',
#   'minWithdrawAmount': '2',
#   'withdrawStatus': False,
#   'depositStatus': True},
#  'PUNDIX': {'withdrawFee': '28',
#   'minWithdrawAmount': '56',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'SPELL': {'withdrawFee': '5886',
#   'minWithdrawAmount': '11772',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'FXS': {'withdrawFee': '1.2',
#   'minWithdrawAmount': '2.4',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'PLA': {'withdrawFee': '8',
#   'minWithdrawAmount': '16',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'EVX': {'withdrawFee': '147',
#   'minWithdrawAmount': '294',
#   'withdrawStatus': True,
#   'depositStatus': False,
#   'depositTip': 'Wallet Maintenance, Deposit Suspended'},
#  'HNST': {'withdrawFee': '10',
#   'minWithdrawAmount': '20',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'CRV': {'withdrawFee': '9.47',
#   'minWithdrawAmount': '18',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'ANT': {'withdrawFee': '4.96',
#   'minWithdrawAmount': '9.92',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'BAKE': {'withdrawFee': '0.26',
#   'minWithdrawAmount': '0.52',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'NU': {'withdrawFee': '46',
#   'minWithdrawAmount': '92',
#   'withdrawStatus': False,
#   'depositStatus': True},
#  'FLUX': {'withdrawFee': '14',
#   'minWithdrawAmount': '28',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'LINKUP': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': False,
#   'depositStatus': False,
#   'depositTip': ''},
#  'ANY': {'withdrawFee': '0.018',
#   'minWithdrawAmount': '0.036',
#   'withdrawStatus': False,
#   'depositStatus': False},
#  'SRM': {'withdrawFee': '7.86',
#   'minWithdrawAmount': '15',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'QISWAP': {'withdrawFee': '1.21',
#   'minWithdrawAmount': '2.42',
#   'withdrawStatus': True,
#   'depositStatus': False},
#  'TORN': {'withdrawFee': '0.52',
#   'minWithdrawAmount': '1.04',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'PLN': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': False,
#   'depositStatus': True},
#  'QNT': {'withdrawFee': '0.19',
#   'minWithdrawAmount': '0.38',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'ETHBEAR': {'withdrawFee': '0',
#   'minWithdrawAmount': '0.0001',
#   'withdrawStatus': False,
#   'depositStatus': False},
#  'ALICE': {'withdrawFee': '3.46',
#   'minWithdrawAmount': '6.92',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'OG': {'withdrawFee': '0',
#   'minWithdrawAmount': '1',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'MFT': {'withdrawFee': '2806',
#   'minWithdrawAmount': '5612',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'OM': {'withdrawFee': '305',
#   'minWithdrawAmount': '610',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'BTTOLD': {'withdrawFee': '400',
#   'minWithdrawAmount': '800',
#   'withdrawStatus': False,
#   'depositStatus': True},
#  'BQX': {'withdrawFee': '0',
#   'minWithdrawAmount': '1',
#   'withdrawStatus': True,
#   'depositStatus': False,
#   'depositTip': 'Wallet Maintenance, Deposit Suspended'},
#  'BETH': {'withdrawFee': '0.0083',
#   'minWithdrawAmount': '0.017',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'WETH': {'withdrawFee': '0.01',
#   'minWithdrawAmount': '0.02',
#   'withdrawStatus': False,
#   'depositStatus': True},
#  'PHBV1': {'withdrawFee': '33',
#   'minWithdrawAmount': '66',
#   'withdrawStatus': False,
#   'depositStatus': True},
#  'BETA': {'withdrawFee': '53',
#   'minWithdrawAmount': '106',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'BRD': {'withdrawFee': '97',
#   'minWithdrawAmount': '194',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'APE': {'withdrawFee': '1.93',
#   'minWithdrawAmount': '3.86',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'SSV': {'withdrawFee': '1.34',
#   'minWithdrawAmount': '2.68',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'BUSD': {'withdrawFee': '15',
#   'minWithdrawAmount': '50',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'CTK': {'withdrawFee': '0.01',
#   'minWithdrawAmount': '0.02',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'ARPA': {'withdrawFee': '306',
#   'minWithdrawAmount': '612',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'BRL': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'DOTDOWN': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': False,
#   'depositStatus': False,
#   'depositTip': ''},
#  'ALCX': {'withdrawFee': '0.22',
#   'minWithdrawAmount': '0.44',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'CTR': {'withdrawFee': '35',
#   'minWithdrawAmount': '70',
#   'withdrawStatus': False,
#   'depositStatus': False,
#   'depositTip': 'Delisted, Deposit Suspended'},
#  'MATIC': {'withdrawFee': '0.1',
#   'minWithdrawAmount': '10',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'IOTX': {'withdrawFee': '0.1',
#   'minWithdrawAmount': '1',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'TVK': {'withdrawFee': '198',
#   'minWithdrawAmount': '396',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'SHIB': {'withdrawFee': '989283',
#   'minWithdrawAmount': '1978566',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'FRONT': {'withdrawFee': '45',
#   'minWithdrawAmount': '90',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'KDA': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'ZAR': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': False,
#   'depositStatus': False},
#  'DOCK': {'withdrawFee': '5',
#   'minWithdrawAmount': '10',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'STX': {'withdrawFee': '1.5',
#   'minWithdrawAmount': '5',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'PNT': {'withdrawFee': '40',
#   'minWithdrawAmount': '80',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'DENT': {'withdrawFee': '8080',
#   'minWithdrawAmount': '16160',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'QI': {'withdrawFee': '5',
#   'minWithdrawAmount': '10',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'MBOX': {'withdrawFee': '0.075',
#   'minWithdrawAmount': '0.15',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'BNBBEAR': {'withdrawFee': '0.011',
#   'minWithdrawAmount': '0.022',
#   'withdrawStatus': False,
#   'depositStatus': False},
#  'SUB': {'withdrawFee': '0',
#   'minWithdrawAmount': '40',
#   'withdrawStatus': False,
#   'depositStatus': False,
#   'depositTip': 'Delisted, Deposit Suspended'},
#  'POA': {'withdrawFee': '0.01',
#   'minWithdrawAmount': '0.02',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'IOST': {'withdrawFee': '1',
#   'minWithdrawAmount': '2',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'POE': {'withdrawFee': '50592',
#   'minWithdrawAmount': '101184',
#   'withdrawStatus': False,
#   'depositStatus': False},
#  'ETHUP': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': False,
#   'depositStatus': False,
#   'depositTip': 'Not support deposit'},
#  'CAKE': {'withdrawFee': '0.025',
#   'minWithdrawAmount': '0.05',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'BSW': {'withdrawFee': '0.35',
#   'minWithdrawAmount': '0.7',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'OMG': {'withdrawFee': '4.76',
#   'minWithdrawAmount': '9.52',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'BAND': {'withdrawFee': '0.01',
#   'minWithdrawAmount': '0.02',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'SUN': {'withdrawFee': '4.71',
#   'minWithdrawAmount': '9.42',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'ASTR': {'withdrawFee': '2',
#   'minWithdrawAmount': '5',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'SUNOLD': {'withdrawFee': '0',
#   'minWithdrawAmount': '0.0058',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'BTC': {'withdrawFee': '0.0005',
#   'minWithdrawAmount': '0.001',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'NKN': {'withdrawFee': '98',
#   'minWithdrawAmount': '196',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'RSR': {'withdrawFee': '1441',
#   'minWithdrawAmount': '2882',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'TWT': {'withdrawFee': '0.18',
#   'minWithdrawAmount': '0.36',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'IOTA': {'withdrawFee': '0.5',
#   'minWithdrawAmount': '69',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'CVC': {'withdrawFee': '71',
#   'minWithdrawAmount': '142',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'REEF': {'withdrawFee': '2218',
#   'minWithdrawAmount': '4436',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'BTG': {'withdrawFee': '0.001',
#   'minWithdrawAmount': '0.002',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'OMR': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': False,
#   'depositStatus': False},
#  'MIR': {'withdrawFee': '22',
#   'minWithdrawAmount': '44',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'KES': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'BTM': {'withdrawFee': '5',
#   'minWithdrawAmount': '10',
#   'withdrawStatus': False,
#   'depositStatus': False,
#   'depositTip': 'Delisted, Deposit Suspended'},
#  'ARK': {'withdrawFee': '0.2',
#   'minWithdrawAmount': '0.4',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'LOKA': {'withdrawFee': '6.14',
#   'minWithdrawAmount': '12',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'CVP': {'withdrawFee': '30',
#   'minWithdrawAmount': '60',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'ARN': {'withdrawFee': '0.26',
#   'minWithdrawAmount': '0.52',
#   'withdrawStatus': False,
#   'depositStatus': False,
#   'depositTip': 'Wallet Maintenance, Deposit Suspended'},
#  'KEY': {'withdrawFee': '3041',
#   'minWithdrawAmount': '6082',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'BTS': {'withdrawFee': '1',
#   'minWithdrawAmount': '2',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'ARS': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'SPARTAOLD': {'withdrawFee': '2',
#   'minWithdrawAmount': '4',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'CVX': {'withdrawFee': '0.91',
#   'minWithdrawAmount': '1.82',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'ONE': {'withdrawFee': '0.1',
#   'minWithdrawAmount': '60',
#   'withdrawStatus': False,
#   'depositStatus': True},
#  'LINKDOWN': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': False,
#   'depositStatus': False,
#   'depositTip': ''},
#  'ONG': {'withdrawFee': '0.04',
#   'minWithdrawAmount': '0.08',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'ANKR': {'withdrawFee': '289',
#   'minWithdrawAmount': '578',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'SUSHI': {'withdrawFee': '6.01',
#   'minWithdrawAmount': '12',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'ALGO': {'withdrawFee': '0.01',
#   'minWithdrawAmount': '10',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'ZCX': {'withdrawFee': '1',
#   'minWithdrawAmount': '2',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'UZS': {'withdrawFee': '1',
#   'minWithdrawAmount': '2',
#   'withdrawStatus': False,
#   'depositStatus': False},
#  'SC': {'withdrawFee': '0.1',
#   'minWithdrawAmount': '0.2',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'WBTC': {'withdrawFee': '0.00058',
#   'minWithdrawAmount': '0.0012',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'ONT': {'withdrawFee': '1',
#   'minWithdrawAmount': '2',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'PPT': {'withdrawFee': '28',
#   'minWithdrawAmount': '56',
#   'withdrawStatus': True,
#   'depositStatus': False,
#   'depositTip': 'Wallet Maintenance, Deposit Suspended'},
#  'ONX': {'withdrawFee': '4.21',
#   'minWithdrawAmount': '8.42',
#   'withdrawStatus': True,
#   'depositStatus': False},
#  'PIVX': {'withdrawFee': '0.2',
#   'minWithdrawAmount': '0.4',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'RUB': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'BTTC': {'withdrawFee': '34042',
#   'minWithdrawAmount': '68084',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'ASR': {'withdrawFee': '0',
#   'minWithdrawAmount': '1',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'FIRO': {'withdrawFee': '0.02',
#   'minWithdrawAmount': '0.04',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'AXSOLD': {'withdrawFee': '0',
#   'minWithdrawAmount': '15',
#   'withdrawStatus': False,
#   'depositStatus': True},
#  'AST': {'withdrawFee': '152',
#   'minWithdrawAmount': '304',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'MANA': {'withdrawFee': '9.99',
#   'minWithdrawAmount': '19',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'DOTUP': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': False,
#   'depositStatus': False,
#   'depositTip': ''},
#  'MEETONE': {'withdrawFee': '300',
#   'minWithdrawAmount': '600',
#   'withdrawStatus': True,
#   'depositStatus': False,
#   'depositTip': 'Not support deposit'},
#  'ATA': {'withdrawFee': '0.46',
#   'minWithdrawAmount': '0.92',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'QSP': {'withdrawFee': '389',
# ...
#  'ZIL': {'withdrawFee': '0.2',
#   'minWithdrawAmount': '0.4',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'AXS': {'withdrawFee': '0.42',
#   'minWithdrawAmount': '0.84',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'VAI': {'withdrawFee': '0.8',
#   'minWithdrawAmount': '10',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'XEM': {'withdrawFee': '4',
#   'minWithdrawAmount': '8',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'CTXC': {'withdrawFee': '0.1',
#   'minWithdrawAmount': '0.2',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'KEYFI': {'withdrawFee': '17',
#   'minWithdrawAmount': '34',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'IHC': {'withdrawFee': '550',
#   'minWithdrawAmount': '1000',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'XTZUP': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': False,
#   'depositStatus': False,
#   'depositTip': 'Not support deposit'},
#  'BIDR': {'withdrawFee': '3222',
#   'minWithdrawAmount': '6444',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'BCHSV': {'withdrawFee': '0.01',
#   'minWithdrawAmount': '0.02',
#   'withdrawStatus': False,
#   'depositStatus': False,
#   'depositTip': 'Delisted, Deposit Suspended'},
#  'AAVEUP': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': False,
#   'depositStatus': False,
#   'depositTip': 'Not support deposit'},
#  'SUSHIDOWN': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': False,
#   'depositStatus': False,
#   'depositTip': 'Not support deposit'},
#  'ETHBNT': {'withdrawFee': '5',
#   'minWithdrawAmount': '5',
#   'withdrawStatus': True,
#   'depositStatus': False,
#   'depositTip': 'Not support deposit'},
#  'COMP': {'withdrawFee': '0.17',
#   'minWithdrawAmount': '0.34',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'OMOLD': {'withdrawFee': '41',
#   'minWithdrawAmount': '82',
#   'withdrawStatus': False,
#   'depositStatus': True},
#  'OOKI': {'withdrawFee': '1880',
#   'minWithdrawAmount': '3760',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'RUNE': {'withdrawFee': '0.019',
#   'minWithdrawAmount': '0.038',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'FORTH': {'withdrawFee': '8.82',
#   'minWithdrawAmount': '17',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'KMD': {'withdrawFee': '0.002',
#   'minWithdrawAmount': '0.004',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'GHST': {'withdrawFee': '12',
#   'minWithdrawAmount': '24',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'ALPINE': {'withdrawFee': '0.031',
#   'minWithdrawAmount': '0.062',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'IDEX': {'withdrawFee': '166',
#   'minWithdrawAmount': '332',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'BNBDOWN': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': False,
#   'depositStatus': False,
#   'depositTip': 'Not support deposit'},
#  'DEXE': {'withdrawFee': '3.92',
#   'minWithdrawAmount': '7.84',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'AVAX': {'withdrawFee': '0.01',
#   'minWithdrawAmount': '0.1',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'AZN': {'withdrawFee': '1',
#   'minWithdrawAmount': '2',
#   'withdrawStatus': False,
#   'depositStatus': False},
#  'UAH': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'KNC': {'withdrawFee': '4',
#   'minWithdrawAmount': '8',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'PROS': {'withdrawFee': '38',
#   'minWithdrawAmount': '76',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'BTCUP': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': False,
#   'depositStatus': False,
#   'depositTip': 'Not support deposit'},
#  'PROM': {'withdrawFee': '2.78',
#   'minWithdrawAmount': '5.56',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'CHAT': {'withdrawFee': '0',
#   'minWithdrawAmount': '200',
#   'withdrawStatus': False,
#   'depositStatus': False,
#   'depositTip': 'Delisted, Deposit Suspended'},
#  'BGBP': {'withdrawFee': '2.81',
#   'minWithdrawAmount': '5.62',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'HIVE': {'withdrawFee': '0.01',
#   'minWithdrawAmount': '0.02',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'LPT': {'withdrawFee': '0.88',
#   'minWithdrawAmount': '1.76',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'BIFI': {'withdrawFee': '0.00015',
#   'minWithdrawAmount': '0.0003',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'PORTO': {'withdrawFee': '0.5',
#   'minWithdrawAmount': '1',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'SNGLS': {'withdrawFee': '1753',
#   'minWithdrawAmount': '3506',
#   'withdrawStatus': True,
#   'depositStatus': False,
#   'depositTip': 'Wallet Maintenance, Deposit Suspended'},
#  'PYR': {'withdrawFee': '2.04',
#   'minWithdrawAmount': '4.08',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'TBCC': {'withdrawFee': '5',
#   'minWithdrawAmount': '10',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'WAXP': {'withdrawFee': '2',
#   'minWithdrawAmount': '7',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'DAI': {'withdrawFee': '15',
#   'minWithdrawAmount': '30',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'YFIUP': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': False,
#   'depositStatus': False,
#   'depositTip': 'Not support deposit'},
#  'FET': {'withdrawFee': '0.5',
#   'minWithdrawAmount': '1.5',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'DAR': {'withdrawFee': '0.2',
#   'minWithdrawAmount': '0.4',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'ETHBULL': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': False,
#   'depositStatus': False},
#  'LRC': {'withdrawFee': '21',
#   'minWithdrawAmount': '42',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'REPV1': {'withdrawFee': '0.1',
#   'minWithdrawAmount': '0.2',
#   'withdrawStatus': False,
#   'depositStatus': True},
#  'MTH': {'withdrawFee': '2541',
#   'minWithdrawAmount': '5082',
#   'withdrawStatus': True,
#   'depositStatus': False,
#   'depositTip': 'Wallet Maintenance, Deposit Suspended'},
#  'ADXOLD': {'withdrawFee': '5',
#   'minWithdrawAmount': '10',
#   'withdrawStatus': False,
#   'depositStatus': True},
#  'MTL': {'withdrawFee': '13',
#   'minWithdrawAmount': '26',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'VET': {'withdrawFee': '20',
#   'minWithdrawAmount': '40',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'ALPACA': {'withdrawFee': '0.46',
#   'minWithdrawAmount': '0.92',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'USDT': {'withdrawFee': '10',
#   'minWithdrawAmount': '50',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'EDG': {'withdrawFee': '100',
#   'minWithdrawAmount': '300',
#   'withdrawStatus': True,
#   'depositStatus': False},
#  'USDS': {'withdrawFee': '2',
#   'minWithdrawAmount': '4',
#   'withdrawStatus': False,
#   'depositStatus': False},
#  'OXT': {'withdrawFee': '93',
#   'minWithdrawAmount': '186',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'DASH': {'withdrawFee': '0.002',
#   'minWithdrawAmount': '0.004',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'NVT': {'withdrawFee': '0.1',
#   'minWithdrawAmount': '1',
#   'withdrawStatus': False,
#   'depositStatus': False},
#  'USDP': {'withdrawFee': '25',
#   'minWithdrawAmount': '50',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'SWRV': {'withdrawFee': '35',
#   'minWithdrawAmount': '70',
#   'withdrawStatus': True,
#   'depositStatus': False},
#  'EDO': {'withdrawFee': '2.23',
#   'minWithdrawAmount': '4.46',
#   'withdrawStatus': True,
#   'depositStatus': False,
#   'depositTip': 'Network Swap, Deposit Closed'},
#  'ILV': {'withdrawFee': '0.042',
#   'minWithdrawAmount': '0.084',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'GHS': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'BTCST': {'withdrawFee': '0.012',
#   'minWithdrawAmount': '0.024',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'HKD': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': False,
#   'depositStatus': True},
#  'JOE': {'withdrawFee': '0.1',
#   'minWithdrawAmount': '1',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'LSK': {'withdrawFee': '0.1',
#   'minWithdrawAmount': '0.2',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'KEEP': {'withdrawFee': '40',
#   'minWithdrawAmount': '80',
#   'withdrawStatus': False,
#   'depositStatus': True},
#  'CAD': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': False,
#   'depositStatus': False},
#  'BEAR': {'withdrawFee': '0',
#   'minWithdrawAmount': '0.00001',
#   'withdrawStatus': False,
#   'depositStatus': False},
#  'BEAM': {'withdrawFee': '0.1',
#   'minWithdrawAmount': '0.2',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'CAN': {'withdrawFee': '5',
#   'minWithdrawAmount': '10',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'DCR': {'withdrawFee': '0.01',
#   'minWithdrawAmount': '0.02',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'CREAM': {'withdrawFee': '0.48',
#   'minWithdrawAmount': '0.96',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'DATA': {'withdrawFee': '325',
#   'minWithdrawAmount': '650',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'IMX': {'withdrawFee': '10',
#   'minWithdrawAmount': '20',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'ENTRP': {'withdrawFee': '10',
#   'minWithdrawAmount': '20',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'FILUP': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': False,
#   'depositStatus': False,
#   'depositTip': 'Not support deposit'},
#  'UNIUP': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': False,
#   'depositStatus': False,
#   'depositTip': 'Not support deposit'},
#  'LTC': {'withdrawFee': '0.001',
#   'minWithdrawAmount': '0.002',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'USDC': {'withdrawFee': '10',
#   'minWithdrawAmount': '50',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'WIN': {'withdrawFee': '212',
#   'minWithdrawAmount': '424',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'BNBBULL': {'withdrawFee': '0.012',
#   'minWithdrawAmount': '0.024',
#   'withdrawStatus': False,
#   'depositStatus': False},
#  'LTCUP': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': False,
#   'depositStatus': False,
#   'depositTip': 'Not support deposit'},
#  'TCT': {'withdrawFee': '1177',
#   'minWithdrawAmount': '2354',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'INJ': {'withdrawFee': '5',
#   'minWithdrawAmount': '10',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'PARA': {'withdrawFee': '10',
#   'minWithdrawAmount': '50',
#   'withdrawStatus': True,
#   'depositStatus': False},
#  'LTO': {'withdrawFee': '5',
#   'minWithdrawAmount': '10',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'VGX': {'withdrawFee': '13',
#   'minWithdrawAmount': '26',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'NXS': {'withdrawFee': '0.02',
#   'minWithdrawAmount': '0.04',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'TRIBE': {'withdrawFee': '47',
#   'minWithdrawAmount': '94',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'DYDX': {'withdrawFee': '16',
#   'minWithdrawAmount': '32',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'EFI': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': False,
#   'depositStatus': False},
#  'AGIX': {'withdrawFee': '185',
#   'minWithdrawAmount': '370',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'INR': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'CBK': {'withdrawFee': '1.2',
#   'minWithdrawAmount': '2.4',
#   'withdrawStatus': True,
#   'depositStatus': False},
#  'LTT': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'INS': {'withdrawFee': '52',
#   'minWithdrawAmount': '104',
#   'withdrawStatus': False,
#   'depositStatus': False},
#  'CBM': {'withdrawFee': '200',
#   'minWithdrawAmount': '400',
#   'withdrawStatus': True,
#   'depositStatus': False,
#   'depositTip': 'Wallet Maintenance, Deposit Suspended'},
#  'POND': {'withdrawFee': '686',
#   'minWithdrawAmount': '1372',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'JPY': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': False,
#   'depositStatus': False,
#   'depositTip': ''},
#  'LINA': {'withdrawFee': '1573',
#   'minWithdrawAmount': '3146',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'XLM': {'withdrawFee': '0.02',
#   'minWithdrawAmount': '40',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'LINK': {'withdrawFee': '1.57',
#   'minWithdrawAmount': '3.14',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'QTUM': {'withdrawFee': '0.01',
#   'minWithdrawAmount': '0.02',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'FILDOWN': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': False,
#   'depositStatus': False,
#   'depositTip': 'Not support deposit'},
#  'UFT': {'withdrawFee': '62',
#   'minWithdrawAmount': '124',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'SUPER': {'withdrawFee': '50',
#   'minWithdrawAmount': '100',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'POLS': {'withdrawFee': '17',
#   'minWithdrawAmount': '34',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'LUN': {'withdrawFee': '0',
#   'minWithdrawAmount': '3.08',
#   'withdrawStatus': False,
#   'depositStatus': False,
#   'depositTip': 'Wallet Maintenance, Deposit Suspended'},
#  'KSM': {'withdrawFee': '0.01',
#   'minWithdrawAmount': '1.01',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'FIL': {'withdrawFee': '0.001',
#   'minWithdrawAmount': '0.01',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'POLY': {'withdrawFee': '53',
#   'minWithdrawAmount': '106',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'STMX': {'withdrawFee': '1281',
#   'minWithdrawAmount': '2562',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'RNDR': {'withdrawFee': '9.03',
#   'minWithdrawAmount': '18',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'FIO': {'withdrawFee': '5',
#   'minWithdrawAmount': '10',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'BAL': {'withdrawFee': '1.65',
#   'minWithdrawAmount': '3.3',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'VIB': {'withdrawFee': '860',
#   'minWithdrawAmount': '1720',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'GALA': {'withdrawFee': '99',
#   'minWithdrawAmount': '198',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'VIA': {'withdrawFee': '0.01',
#   'minWithdrawAmount': '0.02',
#   'withdrawStatus': True,
#   'depositStatus': False},
#  'FIS': {'withdrawFee': '35',
#   'minWithdrawAmount': '70',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'BAR': {'withdrawFee': '0',
#   'minWithdrawAmount': '1',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'RAD': {'withdrawFee': '5.03',
#   'minWithdrawAmount': '10',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'MNTC': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'BAT': {'withdrawFee': '29',
#   'minWithdrawAmount': '58',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'VRAB': {'withdrawFee': '100',
#   'minWithdrawAmount': '200',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'NZD': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': False,
#   'depositStatus': False},
#  'AKRO': {'withdrawFee': '1747',
#   'minWithdrawAmount': '3494',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'MOVR': {'withdrawFee': '0.003',
#   'minWithdrawAmount': '0.006',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  'XMR': {'withdrawFee': '0.0001',
#   'minWithdrawAmount': '0.0002',
#   'withdrawStatus': True,
#   'depositStatus': True},
#  '1INCHDOWN': {'withdrawFee': '0',
#   'minWithdrawAmount': '0',
#   'withdrawStatus': False,
#   'depositStatus': False,
#   'depositTip': 'Not support deposit'},
#  'COTI': {'withdrawFee': '93',
#   'minWithdrawAmount': '186',
#   'withdrawStatus': True,
#   'depositStatus': True}}

# %%
symbol=BTCUSDT
KlinesType='SPOT'
history=pf.historical_data(client,)
